# %%
# import libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Dataset

# %%
df=pd.read_csv("Glass Identification (1).csv")
df
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %%
# Now we can see the colums of the these datasets
df.columns
# Out:
# Index(['1', '1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75',
#        '0.00', '0.00.1', '1.1'],
#       dtype='object')

# %%
# Here we can see top 10 data
df.head(10)
# Out:
#     1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4   6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1
# 5   7  1.51743  13.30  3.60  1.14  73.09  0.58  8.17   0.0    0.00    1
# 6   8  1.51756  13.15  3.61  1.05  73.24  0.57  8.24   0.0    0.00    1
# 7   9  1.51918  14.04  3.58  1.37  72.08  0.56  8.30   0.0    0.00    1
# 8  10  1.51755  13.00  3.60  1.36  72.99  0.57  8.40   0.0    0.11    1
# 9  11  1.51571  12.72  3.46  1.56  73.20  0.67  8.09   0.0    0.24    1

# %%
# Last 10 datas in these datasets
df.tail(10)
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 203  205  1.51617  14.95   0.0  2.27  73.30  0.00  8.71  0.67     0.0    7
# 204  206  1.51732  14.95   0.0  1.80  72.99  0.00  8.61  1.55     0.0    7
# 205  207  1.51645  14.94   0.0  1.87  73.11  0.00  8.67  1.38     0.0    7
# 206  208  1.51831  14.39   0.0  1.82  72.86  1.41  6.47  2.88     0.0    7
# 207  209  1.51640  14.37   0.0  2.74  72.85  0.00  9.45  0.54     0.0    7
# 208  210  1.51623  14.14   0.0  2.88  72.61  0.08  9.18  1.06     0.0    7
# 209  211  1.51685  14.92   0.0  1.99  73.06  0.00  8.40  1.59     0.0    7
# 210  212  1.52065  14.36   0.0  2.02  73.42  0.00  8.44  1.64     0.0    7
# 211  213  1.51651  14.38   0.0  1.94  73.61  0.00  8.48  1.57     0.0    7
# 212  214  1.51711  14.23   0.0  2.08  73.36  0.00  8.62  1.67     0.0    7

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Now we check the how many rows ans columns
df.shape
# Out:
# (213, 11)

# %% [markdown]
# Here we clear see that there is 214 rows and 11 columns contains in these datasets

# %%
print("The dimensions of datasets:", df.shape)
print("The columns of the datasets:", df.columns)
# Out:
# The dimensions of datasets: (213, 11)
# The columns of the datasets: Index(['1', '1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75',
#        '0.00', '0.00.1', '1.1'],
#       dtype='object')

# %%
# describe the data
df.describe()
# Out:
#           1.52101       13.64        4.49        1.10       71.78        0.06  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518353   13.406761    2.676056    1.446526   72.655023    0.499108
# std      0.003039    0.818371    1.440453    0.499882    0.774052    0.653035
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.830000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    3.980000    3.500000   75.410000    6.210000
#
#              8.75        0.00      0.00.1         1.1
# count  213.000000  213.000000  213.000000  213.000000
# mean     8.957934    0.175869    0.057277    2.788732
# std      1.426435    0.498245    0.097589    2.105130
# ...

# %%
# Now we checking null values
df.isnull().sum()
# Out:
# 1          0
# 1.52101    0
# 13.64      0
# 4.49       0
# 1.10       0
# 71.78      0
# 0.06       0
# 8.75       0
# 0.00       0
# 0.00.1     0
# 1.1        0
# dtype: int64

# %% [markdown]
# Here we can see that in these datasets there is no null values present.

# %%
# Lets check the null values using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Count values of each columns
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 1
# 2      1
# 136    1
# 138    1
# 139    1
# 140    1
#       ..
# 76     1
# 77     1
# 78     1
# 79     1
# 214    1
# Name: count, Length: 213, dtype: int64
#
#
# 1.52101
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51761    2
# 1.51613    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: count, Length: 177, dtype: int64
#
#
# 13.64
# 13.21    5
# 13.02    5
# 13.00    5
# 12.85    4
# 12.86    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: count, Length: 142, dtype: int64
#
#
# 4.49
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 3.46     1
# 3.73     1
# 3.97     1
# 3.89     1
# 1.78     1
# Name: count, Length: 93, dtype: int64
#
#
# 1.10
# 1.54    8
# 1.19    6
# 1.56    5
# 1.29    5
# 1.43    5
#        ..
# 1.61    1
# 0.88    1
# 1.05    1
# 0.65    1
# 1.94    1
# Name: count, Length: 117, dtype: int64
#
#
# 71.78
# 72.99    4
# 73.10    4
# ...

# %%
# Now checking the datatypes
df.dtypes
# Out:
# 1            int64
# 1.52101    float64
# 13.64      float64
# 4.49       float64
# 1.10       float64
# 71.78      float64
# 0.06       float64
# 8.75       float64
# 0.00       float64
# 0.00.1     float64
# 1.1          int64
# dtype: object

# %% [markdown]
# Here we can see that all columns containing numerical data

# %%
# Checking for Numerical columns
numerical_col =[]
for i in df.dtypes.index:
    if df.dtypes[i]!= "object":
        numerical_col.append(i)
print("Numerical Columns:", numerical_col)
# Out:
# Numerical Columns: ['1', '1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75', '0.00', '0.00.1', '1.1']

# %%
# Checking number of uniques values in each columns
df.nunique().to_frame("No. of unique values")
# Out:
#          No. of unique values
# 1                         213
# 1.52101                   177
# 13.64                     142
# 4.49                       93
# 1.10                      117
# 71.78                     132
# 0.06                       65
# 8.75                      143
# 0.00                       34
# 0.00.1                     32
# 1.1                         6

# %%
df["1.1"].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# plot the element composition using a bar chart
plt.figure(figsize=(12, 6))
df.drop('1.1', axis=1).plot(kind='bar', stacked=True, cmap='viridis')
plt.title('Element Composition of Glass Samples')
plt.xlabel('Glass Sample ID')
plt.ylabel('Element Concentration')
plt.xticks(rotation=0)
plt.legend(title='Element')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# plot the type of glass distribution
glass_type_counts = df['1.1'].value_counts()
plt.figure(figsize=(8, 6))
glass_type_counts.plot(kind='bar', color='green')
plt.title('Distribution of Glass Types')
plt.xlabel('Glass Type')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Data Distributed

# %%
numerical_col = df.select_dtypes(include=[np.number]).columns.tolist()
plotnumber = 1
plt.figure(figsize=(15,15))
for col in numerical_col:
    if plotnumber <= 25:
        plt.subplot(5, 5, plotnumber)
        sns.histplot(df[col], kde=True, color="m")
        plt.xlabel(col, fontsize=12)
        plotnumber += 1
        plt.tight_layout()
        plt.show()

# %%
plt.figure(figsize = (20,25))
p = 1
for i in df:
    if p<=17:
        plt.subplot(5,4,p)
        sns.scatterplot(x="1.1", y=i, data = df, color = 'r')
        plt.xlabel("1.1")
        plt.ylabel(i)
    p+=1
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,hue = "1.1" , palette="Dark2")
plt.show()

# %% [markdown]
# # Now Checking Outliers

# %%
num_numerical_col= len(numerical_col)
num_row = 5
num_col = 4
total_subplots = num_row * num_col

plt.figure(figsize=(20,16), facecolor="white")

plotnumber = 1
for col in numerical_col:
    if plotnumber <= total_subplots:
        
        ax = plt.subplot(num_row, num_col, plotnumber)
        
        sns.boxplot(x=df[col], palette= "Set2_r", ax=ax)
        
        plt.xlabel(col, fontsize=15)
        plt.ylabel("")
        plt.xticks(rotation=0, fontsize=10)
        plt.yticks(fontsize=10)
        plotnumber += 1
plt.tight_layout()
plt.show()

# %% [markdown]
# Here we can see that all columns contains some outliers so we removed all outliers using IQR method

# %% [markdown]
# # Using IQR method to remove outliers

# %%
columns_of_interest = ['1','1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75', '0.00', '0.00.1', '1.1']
Q1 = df[columns_of_interest].quantile(0.25)
Q3 = df[column_of_interest].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[((df[columns_of_interest] < lower_bound) | (df[columns_of_interest] > upper_bound)).any(axis=1)]

df = df[~((df[columns_of_interest] < lower_bound ) | (df[columns_of_interest] > upper_bound)).any(axis=1)]
  
print("DataFram after removing outliers:")
print(df)
  
print("\nOutliers removed:")
print (outliers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 columns_of_interest = ['1','1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75', '0.00', '0.00.1', '1.1']
#       2 Q1 = df[columns_of_interest].quantile(0.25)
# ----> 3 Q3 = df[column_of_interest].quantile(0.75)
#       4 IQR = Q3 - Q1
#       6 lower_bound = Q1 - 1.5 * IQR
#
# NameError: name 'column_of_interest' is not defined

# %% [markdown]
# # Now cheking skewness

# %%
df.skew()
# Out:
# 1          0.000000
# 1.52101    1.639658
# 13.64      0.457318
# 4.49      -1.154323
# 1.10       0.900017
# 71.78     -0.744546
# 0.06       6.549276
# 8.75       2.040591
# 0.00       3.406749
# 0.00.1     1.747173
# 1.1        1.108861
# dtype: float64

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()
